# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Introduction
#
# The project folder has the following structure:
#
# * In the main directory you have this notebook, `cnn_from_scratch.ipynb`, that contains the instruction and some questions you will have to answer. Follow this notebook and complete the required sections in order.
#
# * In the `src/` directory you have several source files. As instructed in this notebook, you will open and complete those files, then come back to this notebook to execute some tests that will verify what you have done. While these tests don't guarantee that your work is bug-free, they will help you finding the most obvious problems so you will be able to proceed to the next step with confidence.
#
# * Sometimes you will need to restart the notebook. If you do so, remember to execute also the cells containing the code you have already completed starting from the top, before you move on.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
# ### Designing and training a CNN from scratch
#
# In this notebook, you will create a CNN that classifies landmarks.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 50%.
#
# Although 50% may seem low at first glance, it seems more reasonable after realizing how difficult of a problem this is. Many times, an image that is taken at a landmark captures a fairly mundane image of an animal or plant, like in the following picture.
#
# <img src="static_images/train/00.Haleakala_National_Park/084c2aa50d0a9249.jpg" alt="Bird in Haleakalā National Park" style="width: 400px;"/>
#
# Just by looking at that image alone, would you have been able to guess that it was taken at the Haleakalā National Park in Hawaii?
#
# An accuracy of 50% is significantly better than random guessing, which would provide an accuracy of just 2% (100% / 50 classes). In Step 2 of this notebook, you will have the opportunity to greatly improve accuracy by using transfer learning to create a CNN.
#
# Experiment with different architectures, hyperparameters, training strategies, and trust your intuition.  And, of course, have fun!
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly, download the data if you don't have it already, and also check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# !conda info
# Out:
#      active environment : nd230_env
#     active env location : C:\Users\rhelt\anaconda3\envs\nd230_env
#             shell level : 1
#        user config file : C:\Users\rhelt\.condarc
#  populated config files : C:\Users\rhelt\.condarc
#           conda version : 23.7.4
#     conda-build version : 3.26.1
#          python version : 3.11.5.final.0
#        virtual packages : __archspec=1=x86_64
#                           __win=0=0
#        base environment : C:\Users\rhelt\anaconda3  (writable)
#       conda av data dir : C:\Users\rhelt\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\rhelt\anaconda3\pkgs
#                           C:\Users\rhelt\.conda\pkgs
#                           C:\Users\rhelt\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\rhelt\anaconda3\envs
#                           C:\Users\rhelt\.conda\envs
#                           C:\Users\rhelt\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/23.7.4 requests/2.28.1 CPython/3.11.5 Windows/10 Windows/10.0.22621 aau/0.4.0 c/RIQX9yqlKz3a9wM14YbBGA s/NVZpns7JhEukFf8yYAgYKw e/IwBzawe7hkdvgkZUheuvHw
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
# Install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python-headless==4.5.3.56 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 1)) (4.5.3.56)
# Requirement already satisfied: matplotlib==3.4.3 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: numpy==1.21.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 3)) (1.21.2)
# Requirement already satisfied: pillow==10.2.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 4)) (10.2.0)
# Requirement already satisfied: bokeh==2.1.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: torch==1.11.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: torchvision==0.12.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: tqdm==4.63.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: ipywidgets==7.6.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 9)) (7.6.5)
# Requirement already satisfied: livelossplot==0.5.4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: pytest==7.1.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 11)) (7.1.1)
# Requirement already satisfied: pandas==1.3.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: seaborn==0.11.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from -r requirements.txt (line 13)) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (23.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.3.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (4.7.1)
# Requirement already satisfied: requests in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from torchvision==0.12.0->-r requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: colorama in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from tqdm==4.63.0->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.25.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (8.15.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (23.1.0)
# Requirement already satisfied: iniconfig in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from pandas==1.3.5->-r requirements.txt (line 12)) (2023.3.post1)
# Requirement already satisfied: scipy>=1.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from seaborn==0.11.2->-r requirements.txt (line 13)) (1.10.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.6)
# Requirement already satisfied: psutil in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (25.1.0)
# Requirement already satisfied: backcall in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from Jinja2>=2.7->bokeh==2.1.1->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: fastjsonschema in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.4.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2023.11.17)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.10.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.0.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.25.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: wcwidth in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: executing in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.17.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.10.0)
# Requirement already satisfied: overrides in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.4)
# Requirement already satisfied: uri-template in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.5)
# Requirement already satisfied: pycparser in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\rhelt\anaconda3\envs\nd230_env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.8.19.20240106)

# %% [markdown]
# Important! After you have ran pip install, please restart the kernel using the **Kernel** menu

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU *NOT* available. Will use CPU (slow)
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Data
#
# In this and the following steps we are going to complete some code, and then execute some tests to make sure the code works as intended.
#
# Open the file `src/data.py`. It contains a function called `get_data_loaders`. Read the function and complete all the parts marked by `YOUR CODE HERE`. Once you have finished, test that your implementation is correct by executing the following cell (see below for what to do if a test fails):

# %%
# !pytest -vv src/data.py -k data_loaders
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 1 deselected / 3 selected
#
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 3 passed, 1 deselected, 10 warnings in 3.68s =================

# %% [markdown]
# You should see something like:
# ```
# src/data.py::test_data_loaders_keys PASSED                               [ 33%]
# src/data.py::test_data_loaders_output_type PASSED                        [ 66%]
# src/data.py::test_data_loaders_output_shape PASSED                       [100%]
#
# ======================= 3 passed, 1 deselected in 1.81s ========================
# ```
# If all the tests are `PASSED`, you can move to the next section.
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> **What to do if tests fail**
# When a test fails, `pytest` will mark it as `FAILED` as opposed to `PASSED`, and will print a lot of useful output, including a message that should tell you what the problem is. For example, this is the output of a failed test:
# > ```
# >    def test_data_loaders_keys(data_loaders):
# >
# >       assert set(data_loaders.keys()) == {"train", "valid", "test"}
# E       AssertionError: assert {'tes', 'train', 'valid'} == {'test', 'train', 'valid'}
# E         Extra items in the left set:
# E         'tes'
# E         Full diff:
# E         - {'test', 'train', 'valid'}
# E         + {'tes', 'train', 'valid'}
# E         ?                          +++++++
# >
# > src/data.py:171: AssertionError
# -------------- Captured stdout setup ----------------------------------------------
# Reusing cached mean and std for landmark_images
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# =========== short test summary info ===============================================
# FAILED src/data.py::test_data_loaders_keys - AssertionError: The keys of the data_loaders dictionary should be train, valid and test
# > ```
# > In the `short test summary info` you can see a short description of the problem. In this case, the dictionary we are returning has the wrong keys. Going above a little, you can see that the test expects `{'test', 'train', 'valid'}` while we are returning `{'tes', 'train', 'valid'}` (there is a missing `t`). So we can go back to our function, fix that problem and test again.
# >
# > In other cases, you might get an error like:
# > ```
#     def _conv_forward(self, input: Tensor, weight: Tensor, bias: Optional[Tensor]):
#         if self.padding_mode != 'zeros':
#             return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#                             weight, bias, self.stride,
#                             _pair(0), self.dilation, self.groups)
#         return F.conv2d(input, weight, bias, self.stride,
# >                       self.padding, self.dilation, self.groups)
# E       RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
# >
# > ../../../../miniconda3/envs/udacity_starter/lib/python3.7/site-packages/torch/nn/modules/conv.py:440: RuntimeError
# > ```
# > Looking at the stack trace you should be able to understand what it is going on. In this case, we forgot to add a `.cuda()` to some tensor. For example, the model is on the GPU, but the data aren't.

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> **Answer**:
#
#
# **For preprocessing the data, I followed these steps:**
#
# **Image Resizing:** I resized the images to a uniform size to ensure consistency in input dimensions for the CNN. The images were resized to 224x224 pixels, a common choice for CNNs due to its balance between preserving details and computational efficiency.
#
# **Data Augmentation:** To increase the diversity of the training dataset and make the model more robust, I applied data augmentation techniques like random rotations, horizontal flipping, and slight translations. This helps the model generalize better to new, unseen images.
#
# **Normalization:** The images were normalized using mean and standard deviation values computed from the dataset. This normalization helps in speeding up the training and converging the model faster.
#
# **Validation Split:** A portion of the training data (e.g., 20%) was set aside for validation purposes to monitor the model's performance on unseen data during training.

# %% [markdown]
# ### Visualize a Batch of Training Data
#
# Go back to `src/data.py` and complete the function `visualize_one_batch` in all places with the `YOUR CODE HERE` marker. After you're done, execute the following cell and make sure the test `src/data.py::test_visualize_one_batch` is `PASSED`:

# %%
# !pytest -vv src/data.py -k visualize_one_batch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/data.py::test_visualize_one_batch PASSED                             [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 4.06s =================

# %% [markdown]
# We can now use the code we just completed to get a batch of images from your train data loader and look at them.
#
# Visualizing the output of your data loader is a great way to ensure that your data loading and preprocessing (including transforms such as rotations, translations, color transforms...) are working as expected.

# %%
# %matplotlib inline
from src.data import visualize_one_batch, get_data_loaders

# use get_data_loaders to get the data_loaders dictionary. Use a batch_size
# of 5, a validation size of 0.01 and num_workers=-1 (all CPUs)
data_loaders = get_data_loaders(batch_size=5, valid_size=0.01, num_workers=0)  # Adjust num_workers based on your system

visualize_one_batch(data_loaders)
# Out:
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# Reusing cached mean and std

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Define model
#
# Open `src/model.py` and complete the `MyModel` class filling in all the `YOUR CODE HERE` sections. After you're done, execute the following test and make sure it passes:

# %%
# !pytest -vv src/model.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 1 item
#
# src/model.py::test_model_construction PASSED                             [100%]
#
# ============================== warnings summary ===============================
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
# src/model.py::test_model_construction
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 6.13s ========================

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> **Question**: Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/> __Answer:__
#
#
# **For defining the CNN model, I followed these guidelines:**
#
# **Layer Design:** I started with convolutional layers to extract features from the images. I increased the depth of the network gradually, starting with fewer filters and increasing the number to capture more complex patterns.
#
# **Activation Functions:** I used ReLU activation functions for their efficiency and effectiveness in non-linear transformations within the network.
#
# **Pooling Layers:** Pooling layers were used after convolutional layers to reduce the spatial dimensions of the feature maps, thereby reducing the number of parameters and computational complexity.
#
# **Dropout:** To prevent overfitting, dropout layers were introduced, especially in the fully connected layers towards the end of the network.
#
# **Output Layer:** The final layer is a fully connected layer with a number of outputs equal to the number of landmark classes. I used a softmax activation function in the output layer for multi-class classification.
#
# **Experimentation:** I iteratively adjusted the architecture, experimenting with different numbers of layers, filter sizes, and hyperparameters to find a good balance between model complexity and performance.

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: define loss and optimizer
#
# Open `src/optimization.py` and complete the `get_loss` function, then execute the test and make sure it passes:

# %%
# !pytest -vv src/optimization.py -k get_loss
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 7 items / 6 deselected / 1 selected
#
# src/optimization.py::test_get_loss <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [100%]
#
# ======================= 1 passed, 6 deselected in 1.45s =======================

# %% [markdown]
# Then, in the same file, complete the `get_optimizer` function then execute its tests, and make sure they all pass:

# %%
# !pytest -vv src/optimization.py -k get_optimizer
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 7 items / 1 deselected / 6 selected
#
# src/optimization.py::test_get_optimizer_type <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [ 16%]
# src/optimization.py::test_get_optimizer_is_linked_with_model <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [ 33%]
# src/optimization.py::test_get_optimizer_returns_adam <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [ 50%]
# src/optimization.py::test_get_optimizer_sets_learning_rate <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [ 66%]
# src/optimization.py::test_get_optimizer_sets_momentum <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [ 83%]
# src/optimization.py::test_get_optimizer_sets_weight_decat <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\optimization.py PASSED [100%]
#
# ======================= 6 passed, 1 deselected in 1.96s =======================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Train and Validate the Model
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> Testing ML code is notoriously difficult. The tests in this section merely exercise the functions you are completing, so it will help you catching glaring problems but it won't guarantee that your training code is bug-free. If you see that your loss is not decreasing, for example, that's a sign of a bug or of a flawed model design. Use your judgement.
#
# Open `src/train.py` and complete the `train_one_epoch` function, then run the tests:

# %%
# !pytest -vv src/train.py -k train_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_train_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 22.76s ================

# %% [markdown]
# Now complete the `valid` function, then run the tests:

# %%
# !pytest -vv src/train.py -k valid_one_epoch
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_valid_one_epoch PASSED                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 19.04s ================

# %% [markdown]
# Now complete the `optimize` function, then run the tests:

# %%
# !pytest -vv src/train.py -k optimize
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_optimize PASSED                                       [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 37.07s ================

# %% [markdown]
# Finally, complete the `test` function then run the tests:

# %%
# !pytest -vv src/train.py -k one_epoch_test
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 4 items / 3 deselected / 1 selected
#
# src/train.py::test_one_epoch_test PASSED                                 [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ================ 1 passed, 3 deselected, 10 warnings in 15.49s ================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 5: Putting everything together
#
# Allright, good job getting here! Now it's time to see if all our hard work pays off. In the following cell we will train your model and validate it against the validation set.
#
# Let's start by defining a few hyperparameters. Feel free to experiment with different values and try to optimize your model:

# %%
batch_size = 32        # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2       # fraction of the training data to reserve for validation
num_epochs = 50        # number of epochs for training
num_classes = 50       # number of classes. Do not change this
dropout = 0.01          # dropout for our model Changed from .4
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'            # optimizer. 'sgd' or 'adam' Changed to adam
weight_decay = 0.001   # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.train import optimize
from src.optimization import get_optimizer, get_loss
from src.model import MyModel

# get the data loaders using batch_size and valid_size defined in the previous
# cell
# HINT: do NOT copy/paste the values. Use the variables instead
data_loaders = get_data_loaders(batch_size=batch_size, valid_size=valid_size)

# instance model MyModel with num_classes and drouput defined in the previous
# cell
model = MyModel(num_classes=num_classes, dropout=dropout)

# Get the optimizer using get_optimizer and the model you just created, the learning rate,
# the optimizer and the weight decay specified in the previous cell
optimizer = get_optimizer(model=model, optimizer=opt, learning_rate=learning_rate, weight_decay=weight_decay)


# Get the loss using get_loss
loss = get_loss()

optimize(
    data_loaders,
    model,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/best_val_loss.pt",
    interactive_tracking=True
)

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 6: testing against the Test Set
#
# > <img src="static_images/icons/noun-info-2558213.png" alt="?" style="width:25px"/> only run this *after* you have completed hyperpameter optimization. Do not optimize hyperparameters by looking at the results on the test set, or you might overfit on the test set (bad, bad, bad)
#
# Run the code cell below to try out your model on the test dataset of landmark images. Ensure that your test accuracy is greater than 50%.

# %%
# load the model that got the best validation accuracy
from src.train import one_epoch_test
from src.model import MyModel
import torch

model = MyModel(num_classes=num_classes, dropout=dropout)

# Load the weights from the best validation accuracy
model.load_state_dict(torch.load('checkpoints/best_val_loss.pt', map_location=torch.device('cpu')))


# Run test
one_epoch_test(data_loaders['test'], model, loss)
# Out:
# Testing: 100%|██████████████████████████████████| 40/40 [00:38<00:00,  1.05it/s]
# Test Loss: 1.310400
#
#
# Test Accuracy: 67% (846/1250)
# 1.3104003712534904

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 7: Export using torchscript
#
# Great job creating your CNN models! Now that you have put in all the hard work of creating accurate classifiers, let's export it so we can use it in our app.
#
# But first, as usual, we need to complete some code!
#
# Open `src/predictor.py` and fill up the missing code, then run the tests:

# %%
# !pytest -vv src/predictor.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.18, pytest-7.1.1, pluggy-1.3.0 -- C:\Users\rhelt\anaconda3\envs\nd230_env\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\rhelt\jupyter\inwork\nd101
# plugins: anyio-3.5.0
# collecting ... collected 1 item
#
# src/predictor.py::test_model_construction <- ..\..\..\Jupyter notebooks\inwork\nd-101-InWorkTest2\src\predictor.py PASSED [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
# ..\..\..\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345
#   C:\Users\rhelt\anaconda3\envs\nd230_env\lib\site-packages\setuptools\_distutils\version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 5.24s ========================

# %% [markdown]
# Allright, now we are ready to export our model using our Predictor class:

# %%
# NOTE: you might need to restart the notebook before running this step
# If you get an error about RuntimeError: Can't redefine method: forward on class
# restart your notebook then execute only this cell
from src.predictor import Predictor
from src.helpers import compute_mean_and_std
from src.model import MyModel
from src.data import get_data_loaders
import torch

data_loaders = get_data_loaders(batch_size=1)

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model = MyModel(num_classes=50, dropout=0.5).cpu()

# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)

# Load the best weights found during training
model.load_state_dict(torch.load("checkpoints/best_val_loss.pt", map_location='cpu'))

# Wrap model using the Predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model, class_names, mean, std).cpu()

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)

scripted_predictor.save("checkpoints/original_exported.pt")
# Out:
# Reusing cached mean and std
# Dataset mean: tensor([0.4638, 0.4725, 0.4687]), std: tensor([0.2699, 0.2706, 0.3018])
# Reusing cached mean and std
# Reusing cached mean and std

# %% [markdown]
# Now let's make sure the exported model has the same performance as the original one, by reloading it and testing it. The Predictor class takes different inputs than the non-wrapped model, so we have to use a specific test loop:

# %%
import torch

# Load using torch.jit.load
model_reloaded =  torch.jit.load("checkpoints/original_exported.pt")

# %%
from src.predictor import predictor_test

pred, truth = predictor_test(data_loaders['test'], model_reloaded)
# Out:
# 100%|███████████████████████████████████████| 1250/1250 [01:10<00:00, 17.66it/s]
# Accuracy: 0.664

# %% [markdown]
# Finally, let's have a look at the confusion matrix of the model we are going to use in production:

# %%
from src.helpers import plot_confusion_matrix

plot_confusion_matrix(pred, truth)
